# %% [markdown]
# # Check if output of `pymupdf-wf` is valid

# %%
from pathlib import Path
import os
import json

# %%
p = Path('/eagle/projects/argonne_tpc/siebenschuh/aurora_gpt/joint_to_pymupdf/parsed_pdfs')

# %%
json_paths = [p/ f for f in os.listdir(p) if f.endswith('.jsonl')]
data_list = []
for j_p in json_paths:
    print(f"Reading file: {j_p}")
    
    # Open and read the .jsonl file
    with open(j_p, 'r') as file:
        # Iterate over each line in the .jsonl file
        for line in file:
            # Parse the line as a JSON object
            data = json.loads(line)
            data_list.append(data)

    print(f"Finished reading file: {j_p}\n")
# Out:
# Reading file: /eagle/projects/argonne_tpc/siebenschuh/aurora_gpt/joint_to_pymupdf/parsed_pdfs/09e234d0-7cbe-4c2d-aec4-2c79788c8b2d.jsonl
# Finished reading file: /eagle/projects/argonne_tpc/siebenschuh/aurora_gpt/joint_to_pymupdf/parsed_pdfs/09e234d0-7cbe-4c2d-aec4-2c79788c8b2d.jsonl
#
# Reading file: /eagle/projects/argonne_tpc/siebenschuh/aurora_gpt/joint_to_pymupdf/parsed_pdfs/4066ba14-33e9-41d2-9f2a-a9232bd7b2b1.jsonl
# Finished reading file: /eagle/projects/argonne_tpc/siebenschuh/aurora_gpt/joint_to_pymupdf/parsed_pdfs/4066ba14-33e9-41d2-9f2a-a9232bd7b2b1.jsonl
#
# Reading file: /eagle/projects/argonne_tpc/siebenschuh/aurora_gpt/joint_to_pymupdf/parsed_pdfs/88c1c638-a752-4dfa-9f9d-dcfbf92d614d.jsonl
# Finished reading file: /eagle/projects/argonne_tpc/siebenschuh/aurora_gpt/joint_to_pymupdf/parsed_pdfs/88c1c638-a752-4dfa-9f9d-dcfbf92d614d.jsonl
#
# Reading file: /eagle/projects/argonne_tpc/siebenschuh/aurora_gpt/joint_to_pymupdf/parsed_pdfs/0823823c-ff36-48ea-ab27-ef14fe62bc0d.jsonl
# Finished reading file: /eagle/projects/argonne_tpc/siebenschuh/aurora_gpt/joint_to_pymupdf/parsed_pdfs/0823823c-ff36-48ea-ab27-ef14fe62bc0d.jsonl

# %%
len(data_list)
# Out:
# 24980

# %%
print('Number of unique PDFs parsed: ', len(set([f['path'] for f in data_list])))
# Out:
# Number of unique PDFs parsed:  24980

# %%
[Path(f['path']).parent.parent.name for f in data_list if f['metadata']['doi']!='']
# Out:
# ['medrxiv',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'arxiv',
#  'arxiv',
#  'arxiv',
#  'arxiv',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'bmc',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  'nature',
#  ...]
