# %% [markdown]
# # Check if output of `pymupdf-wf` is valid

# %%
from pathlib import Path
import os
import json

# %%
p = Path('/lus/eagle/projects/argonne_tpc/siebenschuh/aurora_gpt/tiny_test_pdf_set_to_pymupdf/parsed_pdfs')

# %%
json_paths = [p/ f for f in os.listdir(p) if f.endswith('.jsonl')]
data_list = []
for j_p in json_paths:
    print(f"Reading file: {j_p}")
    
    # Open and read the .jsonl file
    with open(j_p, 'r') as file:
        # Iterate over each line in the .jsonl file
        for line in file:
            # Parse the line as a JSON object
            data = json.loads(line)
            data_list.append(data)

    print(f"Finished reading file: {j_p}\n")
# Out:
# Reading file: /lus/eagle/projects/argonne_tpc/siebenschuh/aurora_gpt/tiny_test_pdf_set_to_pymupdf/parsed_pdfs/019285e4-e8e4-4bc9-a9fc-8ba52f779ec3.jsonl
# Finished reading file: /lus/eagle/projects/argonne_tpc/siebenschuh/aurora_gpt/tiny_test_pdf_set_to_pymupdf/parsed_pdfs/019285e4-e8e4-4bc9-a9fc-8ba52f779ec3.jsonl
#
# Reading file: /lus/eagle/projects/argonne_tpc/siebenschuh/aurora_gpt/tiny_test_pdf_set_to_pymupdf/parsed_pdfs/aa31f139-3ee9-4d4a-999d-09f4da9786a2.jsonl
# Finished reading file: /lus/eagle/projects/argonne_tpc/siebenschuh/aurora_gpt/tiny_test_pdf_set_to_pymupdf/parsed_pdfs/aa31f139-3ee9-4d4a-999d-09f4da9786a2.jsonl
#
# Reading file: /lus/eagle/projects/argonne_tpc/siebenschuh/aurora_gpt/tiny_test_pdf_set_to_pymupdf/parsed_pdfs/6ab18530-3ae4-4ddf-8635-b950f14e6c52.jsonl
# Finished reading file: /lus/eagle/projects/argonne_tpc/siebenschuh/aurora_gpt/tiny_test_pdf_set_to_pymupdf/parsed_pdfs/6ab18530-3ae4-4ddf-8635-b950f14e6c52.jsonl
#
# Reading file: /lus/eagle/projects/argonne_tpc/siebenschuh/aurora_gpt/tiny_test_pdf_set_to_pymupdf/parsed_pdfs/5ab63457-223b-4e35-93a4-563f1274975f.jsonl
# Finished reading file: /lus/eagle/projects/argonne_tpc/siebenschuh/aurora_gpt/tiny_test_pdf_set_to_pymupdf/parsed_pdfs/5ab63457-223b-4e35-93a4-563f1274975f.jsonl

# %%
for data in data_list:
    print(data['metadata']['doi'])
# Out:
# 10.1186/s12938-024-01238-8
#
#
#
#
# 10.1186/s40550-022-00089-2
#
# 10.1038/nature25979
#
# 10.1186/s13321-023-00739-3
#
#
#
#
# 10.1186/s13036-020-00253-2
#
# 10.1038/s41586-020-3007-0
# 10.1186/s13036-016-0038-z
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 10.1186/s13321-024-00851-y
#
#
#
#
#
#
#
# 10.1186/s13326-017-0163-8
#
#
#
# 10.1038/nature17936
#
#
#
# 10.1186/s13705-016-0095-7
#
# 10.1038/s41586-022-05571-7
# 10.1038/s41586-020-2931-3
#
# 10.1186/s13321-023-00746-4
# 10.1038/s41586-018-0482-7
#
#
# 10.1186/s13705-018-0174-z
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 10.1186/s12938-024-01215-1
#
#
#
#
#
#
# 10.1186/s13321-022-00673-w
# 10.1186/s13321-023-00764-2
#
#
# 10.1038/s41586-024-07803-4
#
#
# 10.1186/s13321-022-00624-5
#
#
# 10.1038/nature17967
# 10.1186/s13321-024-00876-3
#
#
#
# 10.1186/s13705-022-00350-8
#
#
#
#
# 10.1038/s41586-022-05513-3
