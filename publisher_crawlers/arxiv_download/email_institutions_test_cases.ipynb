# %%
ten_examples_provided = [
    'https://arxiv.org/html/2405.01297v1',
    'https://arxiv.org/html/2407.19909v1',
    'https://arxiv.org/html/2408.00041v1',
    'https://arxiv.org/html/2408.00614v1',
    'https://arxiv.org/html/2408.00721v1',
]

ten_expected_outputs = [
{'emails': {'Giulia Cusin' : 'cusin@iap.fr', 'Cyril Pitrou' : 'pitrou@iap.fr', 'Camille Bonvin' : 'camille.bonvin@unige.ch', 
            'Aurélien Barrau' : 'barrau@lpsc.in2p3.fr'},
 'institutions': {'Institut d’Astrophysique de Paris, UMR-7095 du CNRS et de Sorbonne Université, Paris, France' : ['Giulia Cusin', 'Cyril Pitrou'],
                  'Département de Physique Théorique and Center for Astroparticle Physics, Université de Genève, Quai E. Ansermet 24, CH-1211 Genève 4, Switzerland' : ['Giulia Cusin','Camille Bonvin'],
                  'Laboratoire de Physique Subatomique et de Cosmologie, Univ. Grenoble-Alpes, CNRS-IN2P3, 53 av. des Martyrs, 38026 Grenoble, France' : ['Aurélien Barrau', 'Killian Martineau']}},

    {'emails': {'unknown_author_1' : 'r.m.vanwesten@uu.nl', 'Elian Y.P. Vanderborght' : 'e.y.p.vanderborght@uu.nl', 'Michael Kliphuis' : 'm.kliphuis@uu.nl', 'Henk A. Dijkstra' : 'h.a.dijkstra@uu.nl'},
     'institutions': {}
},
{'emails': {"Junru Chen": "jrchen_cali@zju.edu.cn",
    "Tianyu Cao": "ty.cao@zju.edu.cn",
    "Jing Xu": "ltxu1111@gmail.com",
    "Jiahe Li": "jiaheli@zju.edu.cn",
    "Zhilong Chen": "zhilongchen@zju.edu.cn",
    "Tao Xiao": "xtxjtu@163.com",
    "Yang Yang": "yangya@zju.edu.cn"
}, 'institutions': {"Zhejiang University": ["Junru Chen", "Tianyu Cao", "Jiahe Li", "Zhilong Chen", "Yang Yang"],
    "State Grid Power Supply Co. Ltd.": ["Tao Xiao", "Jing Xu"]}
},
{'emails': {'Teresa Bister' : 'teresa.bister@ru.nl', 'Glennys R. Farrar' : 'gf25@nyu.edu', 'Michael Unger' : 'michael.unger@kit.edu'},
 'institutions': {'Institute for Mathematics, Astrophysics and Particle Physics, Radboud University Nijmegen, Nijmegen, The Netherlands' : ['Teresa Bister'],
                  'Nationaal Instituut voor Subatomaire Fysica (NIKHEF), Science Park, Amsterdam, The Netherlands' : ['Teresa Bister'],
                  'Center for Cosmology and Particle Physics, New York University, New York, NY 10003, USA' : ['Glennys R. Farrar'],
                  'Institute for Astroparticle Physics, Karlsruhe Institute of Technology (KIT), Karlsruhe, Germany' : ['Michael Unger'],
                  'Institutt for fysikk, Norwegian University of Science and Technology (NTNU), Trondheim, Norway' : ['Michael Unger'],
                 }
},
{'emails': {'L. Bernal-González' : 'lbernal@us.es', 'M.C. Calderón-Moreno' : 'mccm@us.es', 'J. López-Salazar' : 'jeronimo.lopezsalazar@upm.es', 'J.A. Prado-Bassas' : 'bassas@us.es'},
 'institutions': {'Departamento de Análisis Matemático Facultad de Matemáticas Instituto de Matemáticas de la Universidad de Sevilla (IMUS) Universidad de Sevilla Avenida Reina Mercedes s/n, 41012-Sevilla (Spain).' : ['L. Bernal-González', 'M.C. Calderón-Moreno', 'J.A. Prado-Bassas'],
                  'Departamento de Matemática Aplicada a las Tecnologías de la Información y de las Comunicaciones Escuela Técnica Superior de Ingeniería y Sistemas de Telecomunicación Universidad Politécnica de Madrid Nikola Tesla s/n, 28031-Madrid (Spain).' : ['J. López-Salazar']}
},
    {'emails': {'L. Martelli' : 'lorenzo.martelli295@gmail.com', 'O. Kononenko' : '', 'I. A. Andriyash' : '', 'J. Wheeler' : '', 'J. Gautier' : '', 'J.-P Goddet' : '', 'A. Tafzi' : '', 'R. Lahaye' : '', 'C. Giaccaglia' : '', 'A. Flacco' : '', 'V. Tomkus' : '', 'M. Mackevičiūtė' : '',  'J. Dudutis' : '', 'V. Stankevic' : '', 'P. Gečys' : '',  'G. Račiukaitis' : '', 'H. Kraft' : '', 'X. Q. Dinh' : '', 'C. Thaury' : 'cedric.thaury@ensta-paris.fr'},
 'institutions': {'LOA, École Polytechnique, ENSTA ParisTech, CNRS, Université Paris-Saclay, 828 Boulevard des Maréchaux, 91762 Palaiseau Cedex, France' : ['L. Martelli', 'O. Kononenko', 'I. A. Andriyash', 'J. Wheeler', 'J. Gautier', 'J.-P Goddet', 'A. Tafzi', 'R. Lahaye', 'C. Giaccaglia', 'A. Flacco', 'C. Thaury'],
                  'THALES AVS - MIS, 2 Rue Marcel Dassault, Vélizy-Villacoublay, 78140, France' : ['L. Martelli', 'X. Q. Dinh'],
                  'Institut Curie, Inserm U 1021-CNRS UMR 3347, University Paris-Saclay, PSL Research University, Centre Universitaire, Orsay, 91471, France' : ['C. Giaccaglia'],
                  'Unknown_institution_1' : ['V. Tomkus', 'M. Mackevičiūtė', 'J. Dudutis', 'V. Stankevic', 'P. Gečys'],
                  'FTMC - Center for Physical Sciences and Technology, Savanoriu Ave. 231, Vilnius, LT-2300, Lithuania' : ['G. Račiukaitis'],
                 }
},
{'emails': {'David March-Pons' : 'david.march@upc.edu', 'Romualdo Pastor-Satorras' : '', 'M. Carmen Miguel' : ''},
 'institutions': {'Departament de Física, Universitat Politècnica de Catalunya, Campus Nord B4, 08034 Barcelona, Spain' : ['David March-Pons', 'Romualdo Pastor-Satorras'],
                  'Departament de Física de la Matèria Condensada, Universitat de Barcelona, Martí i Franquès 1, 08028 Barcelona, Spain' : ['David March-Pons',  'M. Carmen Miguel'],
                  'Institute of Complex Systems (UBICS), Universitat de Barcelona, 08028 Barcelona, Spain' : ['M. Carmen Miguel']
                 }
},
    ,
    {'emails': {'Chris Verhoek' : 'c.verhoek@tue.nl', 'Roland Tóth' : ''},
 'institutions': {'Unknown_institution' : ['Chris Verhoek',  'Roland Tóth']}
},
,
    {'emails': {'T. Thiemann' : 'thomas.thiemann@gravity.fau.de'},
 'institutions': {'Inst. for Quantum Gravity, FAU Erlangen – Nürnberg, Staudtstr. 7, 91058 Erlangen, Germany' : ['T. Thiemann']}
},
,
    {'emails': {'Patrick Kuiper' : 'patrick.kuiper@duke.edu', 'Ali Hasan' : '', 'Wenhao Yang' : '', 'Yuting Ng' : '', 'Hoda Bidkhori' : '', 'Jose Blanchet' : '', 'Vahid Tarokh' : ''},
 'institutions': {'Dept. of Electrical and Computer Engineering Duke University Durham, North Carolina, USA' : ['Patrick Kuiper', 'Ali Hasan', 'Yuting Ng', 'Vahid Tarokh'],
                  'Dept. of Management Science and Engineering Stanford University Stanford, California, USA' : ['Wenhao Yang', 'Jose Blanchet'],
                  'Computational and Data Sciences Dept. George Mason University Fairfax, Virginia, USA' : ['Hoda Bidkhori'],
                 }
}
]

ten_comments = [
    'There are 4 authors. All of them have an email address displayed. Some are associated with multiple research institutions. \
     Each Author has the email and institution underneath their name. `ltx_authors` appears to contain all author-relevant information (name, email, institution) while each element `ltx_author_notes` contains all information items that are required. \
     Since insitution names appear multiple times the method needs to implicitely match author names and assign them to the respective dictionary key (instituton names).',
    'There are 4 authors although only 3 author names are provided. The first author name was likely forgotten. So we store the email under `unknown_author_1` which is used as a placeholder. Please note that the Author names are distorted by the (HTML?) commands `\fnm` and `\sur`, for first name and surname, respectively. These should be filtered out when parsing the names. If more emails are not assignable to an author additional `unknown_author_{X}` are added \
     These virtual authornames are also to be used when listing in the institutions. Regardless, since there is no institution listed near the author names or title, that dictionary is empty.',
    'Ok, case 3. This example deviates slightly more as all author information is stored in a single element `ltx_personname`. Moreover, authors are only separated by `&` making the parsing slightly more difficult.',
    'Note that several authors are assigned multiple institutions. This is not uncommon and should be handled. As before, `ltx_authors` appears to hold the elements each containing the author information.',
    'Several authors (4) with author_notes containing all elements for each author required to construct the dictionaries. Note that the email addresses come after the institution. This is not unusual.',
    'There are many authors on this one. Regardless, only few have email addresses assigned to them. `ltx_authors` holds all the information. Some authors have no institution assigned to them. Assign the virtual institution name `Unknown_institution`. `Unknown_institution` serves as a catch-all for every author name that cannot be assigned to (at least one) other institution.',
    'Only one author has an email address provided under `ltx_contact ltx_role_email`. Some authors have multiple institutions assigned to them. `ltx_contact ltx_role_affiliation` stores the institution appearently.',
    '`ltx_personname` stores the names of both authors (separated by ` and `). This can occur although rarely. Split the names according to `, ` and ` and ` in such cases. \
The email address at the end is misplaced as it can be found under `ltx_text ltx_font_typewritter`. Finding it likely requires parsing for strings with `@` and `.` in them. The institution information is so deeply buried in an acknowledgment paragraph, that it can be left out. In turn, both authors are assigned 'Unknown_insitution'. If, however, for consistency reasons for other cases the entire acknowledgment section under  `ltx_author_notes` has to be considered an institution with both authors assigned to it, that is perfectly acceptable output too.'
]
# Out:
#   Cell In[1], line 55
#     ,
#     ^
# SyntaxError: invalid syntax

# %%
{'David March-Pons' : 'david.march@upc.edu', 'Romualdo Pastor-Satorras' : '', 'M. Carmen Miguel' : ''}

# %%
{'emails': {},
 'institutions': {}
}


r.m.vanwesten@uu.nl
\fnmElian Y.P. \surVanderborght
e.y.p.vanderborght@uu.nl
\fnmMichael \surKliphuis
m.kliphuis@uu.nl
\fnmHenk A. \surDijkstra
h.a.dijkstra@uu.nl
[



{'emails': {'unknown_author_1' : 'r.m.vanwesten@uu.nl', 'Elian Y.P. Vanderborght' : 'e.y.p.vanderborght@uu.nl', 'Michael Kliphuis' : 'm.kliphuis@uu.nl', 'Henk A. Dijkstra' : 'h.a.dijkstra@uu.nl'},
 'institutions': {}
}
