# %%
import pandas as pd
from nature_urls import nature_urls
from pathlib import Path
import time
import random

from mvp_nature_utils import Nature_Spyder

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.action_chains import ActionChains

# %%
random.shuffle(nature_urls)
nature_subset_urls = nature_urls[:1]
time.sleep(2)

# scrape
spyder = Nature_Spyder(nature_subset_urls)
spyder.scrape_all()
# Out:
# Title: A plant-derived natural photosynthetic system for improving cell anabolism
# Title: A nearby long gamma-ray burst from a merger of compact objects
# Title: Close relatives of MERS-CoV in bats use ACE2 as their functional receptors
# Error scraping article: Message: no such element: Unable to locate element: {"method":"css selector","selector":"span.u-color-open-access"}
#   (Session info: chrome-headless-shell=127.0.6533.99); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# #0 0x5602b0fcf6aa <unknown>
# #1 0x5602b0ca0600 <unknown>
# #2 0x5602b0cefbcb <unknown>
# #3 0x5602b0cefeb1 <unknown>
# #4 0x5602b0ce46a6 <unknown>
# #5 0x5602b0d128cd <unknown>
# #6 0x5602b0ce4599 <unknown>
# #7 0x5602b0d12a6e <unknown>
# #8 0x5602b0d3104a <unknown>
# #9 0x5602b0d12643 <unknown>
# #10 0x5602b0ce2d31 <unknown>
# #11 0x5602b0ce379e <unknown>
# #12 0x5602b0f9723b <unknown>
# ...

# %%
spyder.article_url_list
# Out:
# ['https://www.nature.com/articles/s41586-022-05499-y',
#  'https://www.nature.com/articles/s41586-022-05327-3',
#  'https://www.nature.com/articles/s41586-022-05513-3',
#  'https://www.nature.com/articles/s41586-022-05466-7',
#  'https://www.nature.com/articles/s41586-022-05501-7',
#  'https://www.nature.com/articles/s41586-022-05504-4',
#  'https://www.nature.com/articles/s41586-022-05509-z',
#  'https://www.nature.com/articles/s41586-022-05511-5',
#  'https://www.nature.com/articles/s41586-022-05495-2',
#  'https://www.nature.com/articles/s41586-022-05450-1',
#  'https://www.nature.com/articles/s41586-022-05507-1',
#  'https://www.nature.com/articles/s41586-022-05502-6',
#  'https://www.nature.com/articles/s41586-022-05403-8',
#  'https://www.nature.com/articles/s41586-022-05422-5',
#  'https://www.nature.com/articles/s41586-022-05505-3',
#  'https://www.nature.com/articles/s41586-022-05453-y',
#  'https://www.nature.com/articles/s41586-022-05608-x',
# ...
